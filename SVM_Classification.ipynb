# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

from dataset import parse_data
from utils import *

# %%
# Function to generate the required plots
def plot_data(X, Y, title=''):
    fig, ax = plt.subplots()
    scatter = ax.scatter(X[:, 0], X[:,1], c=Y)
    ax.set_title(title)
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    legend = ax.legend(*scatter.legend_elements(), title="Classes")
    ax.add_artist(legend)
    plt.show()

# %% [markdown]
# # Linearly Separable Data

# %%
# Reading the data
root_dir = os.path.join('dataset', 'linearlySeparable')
X_train, Y_train = parse_data(root_dir, 'train')
X_val, Y_val = parse_data(root_dir, 'val')
X_test, Y_test = parse_data(root_dir, 'test')

# %%
# Using the One-vs-Rest SVM Classifier under linear kernel
classifier = svm.SVC(kernel = 'linear', decision_function_shape = 'ovr')
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
# Make predictions using the classifier
pred_y = classifier.predict(X_test)

# %%
# Visualizaing the actual and predicted classes
plot_data(X_test, Y_test, 'Actual Test Classes')
plot_data(X_test, pred_y, 'Predicted Test Classes')

# %%
# Decision Region with Training Data
plot_decision_regions(X_train, Y_train, clf=classifier)
# Out:
# c:\Users\dsouz\Desktop\iml_assignment\utils.py:110: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x=x_data,
# <AxesSubplot:>

# %%
# Decision Region with Test Data
plot_decision_regions(X_test, Y_test, clf=classifier)
# Out:
# c:\Users\dsouz\Desktop\iml_assignment\utils.py:110: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x=x_data,
# <AxesSubplot:>

# %%
# Performance Evaluation Metrics
confusion_matrix(Y_test, pred_y)
metrics_summary(Y_test, pred_y)
# Out:
# Mean Accuracy: 1.00
# Mean Precision: 1.00
# Mean Recall: 1.00
# Mean F-measure: 1.00
#
# Recall for class 1: 1.00
# Recall for class 2: 1.00
# Recall for class 3: 1.00
# Recall for class 4: 1.00
#
# F-measure for class 1: 1.00
# F-measure for class 2: 1.00
# F-measure for class 3: 1.00
# F-measure for class 4: 1.00

# %% [markdown]
# # Overlapping Data

# %%
# Reading the data
root_dir = os.path.join('dataset', 'overlapping')
X_train, Y_train = parse_data(root_dir, 'train')
X_val, Y_val = parse_data(root_dir, 'val')
X_test, Y_test = parse_data(root_dir, 'test')

# %%
# Using the One-vs-Rest SVM Classifier under polynomial kernel
classifier = svm.SVC(kernel = 'poly', degree= 3, decision_function_shape = 'ovr')
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='poly')

# %%
# Make predictions using the classifier
pred_y = classifier.predict(X_test)

# %%
# Visualizaing the actual and predicted classes
plot_data(X_test, Y_test, 'Actual Test Classes')
plot_data(X_test, pred_y, 'Predicted Test Classes')

# %%
# Decision Region with Training Data
plot_decision_regions(X_train, Y_train, clf=classifier)
# Out:
# <AxesSubplot:>

# %%
# Decision Region with Test Data
plot_decision_regions(X_test, Y_test, clf=classifier)
# Out:
# <AxesSubplot:>

# %%
# Performance Evaluation Metrics
confusion_matrix(Y_test, pred_y)
metrics_summary(Y_test, pred_y)
# Out:
# Mean Accuracy: 0.90
# Mean Precision: 0.90
# Mean Recall: 0.90
# Mean F-measure: 0.90
#
# Recall for class 1: 0.86
# Recall for class 2: 0.90
# Recall for class 3: 0.95
#
# F-measure for class 1: 0.86
# F-measure for class 2: 0.92
# F-measure for class 3: 0.94

# %% [markdown]
# # Non Linearly Separable Data

# %%
# Reading the data
root_dir = os.path.join('dataset', 'nonLinearlySeparable')
X_train, Y_train = parse_data(root_dir, 'train')
X_val, Y_val = parse_data(root_dir, 'val')
X_test, Y_test = parse_data(root_dir, 'test')

# %%
# Using the One-vs-Rest SVM Classifier under polynomial kernel
classifier = svm.SVC(kernel = 'rbf', gamma = 'auto', decision_function_shape = 'ovr')
classifier.fit(X_train, Y_train)
# Out:
# SVC(gamma='auto')

# %%
# Make predictions using the classifier
pred_y = classifier.predict(X_test)

# %%
# Visualizaing the actual and predicted classes
plot_data(X_test, Y_test, 'Actual Test Classes')
plot_data(X_test, pred_y, 'Predicted Test Classes')

# %%
# Decision Region with Training Data
plot_decision_regions(X_train, Y_train, clf=classifier)
# Out:
# <AxesSubplot:>

# %%
# Decision Region with Test Data
plot_decision_regions(X_test, Y_test, clf=classifier)
# Out:
# <AxesSubplot:>

# %%
# Performance Evaluation Metrics
confusion_matrix(Y_test, pred_y)
metrics_summary(Y_test, pred_y)
# Out:
# Mean Accuracy: 1.00
# Mean Precision: 1.00
# Mean Recall: 1.00
# Mean F-measure: 1.00
#
# Recall for class 1: 1.00
# Recall for class 2: 1.00
#
# F-measure for class 1: 1.00
# F-measure for class 2: 1.00
